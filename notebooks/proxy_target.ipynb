# %%
from datetime import timedelta
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import pandas as pd

import sys
sys.path.insert(1, '../src')
from feature_extractor import preprocess_features, aggregate_customer_features, iv_woe

# %%
def calculate_rfm(df, snaphot_date=None):
    """
    Calculate RFM (Recency, Frequency, Monetary) features from a DataFrame.
    
    Parameters:
    df (DataFrame): Input DataFrame containing 'CustomerId', 'transaction_date', and 'amount'.
    snaphot_date (datetime, optional): The date to consider as the snapshot for recency calculation.
    
    Returns:
    DataFrame: A DataFrame with RFM features.
    """
    if snaphot_date is None:
        snaphot_date = df['TransactionStartTime'].max() + timedelta(days=1)
    
    rfm = df.groupby('CustomerId').agg({
        'TransactionStartTime': lambda x: (snaphot_date - x.max()).days,
        'TransactionId': 'count',
        'Amount': 'sum'
    }).rename(
        columns={
            'TransactionStartTime': 'Recency',
            'TransactionId': 'Frequency',
            'Amount': 'Monetary'
        }
    ).reset_index()
    
    rfm.columns = ['CustomerId', 'Recency', 'Frequency', 'Monetary']
    
    return rfm

# %%
def scale_rfm(rfm_df):
    rfm_values = rfm_df[['Recency', 'Frequency', 'Monetary']]
    scaler = StandardScaler()
    scaled_rfm = scaler.fit_transform(rfm_values)

    return scaled_rfm, scaler

# %%
def create_rfm_clusters(scaled_rfm, random_state=42):
    kmeans = KMeans(n_clusters=3, random_state=random_state)
    clusters = kmeans.fit_predict(scaled_rfm)
    return clusters

# %%
def assign_proxy_label(rfm_df, clusters):
    rfm_df['cluster'] = clusters

    # Compute mean values per cluster to identify least engaged one
    cluster_profile = rfm_df.groupby('cluster')[['Recency', 'Frequency', 'Monetary']].mean().reset_index()
    print (cluster_profile)

    # Let's assume lowest frequency & monitary = high risk

    high_risk_cluster = cluster_profile.sort_values(by=['Frequency', 'Monetary']).index[0]
    rfm_df['is_high_risk'] = (rfm_df['cluster'] == high_risk_cluster).astype(int)

    return rfm_df

# %%
df = pd.read_csv('../data/raw/data.csv')
df['TransactionStartTime'] = pd.to_datetime(df['TransactionStartTime'])

# %%
rfm = calculate_rfm(df)
scale_rfm, scaler = scale_rfm(rfm)

# %%
clusters = create_rfm_clusters(scale_rfm)
rfm_labeled = assign_proxy_label(rfm, clusters)
df_labeled = df.merge(rfm_labeled[['CustomerId', 'is_high_risk']], on='CustomerId', how='left')
# Out:
#    cluster    Recency    Frequency      Monetary
# 0        0  61.859846     7.726699  8.172379e+04
# 1        1  29.000000  4091.000000 -1.049000e+08
# 2        2  12.716076    34.807692  2.726546e+05

# %%
df_labeled.sample(5)
# Out:
#               TransactionId         BatchId       AccountId  \
# 45670  TransactionId_134070  BatchId_120673  AccountId_4841
# 25855  TransactionId_108126   BatchId_80047  AccountId_2314
# 61556   TransactionId_70966   BatchId_11914  AccountId_2040
# 80669   TransactionId_61985   BatchId_79277  AccountId_4841
# 35397   TransactionId_37785   BatchId_78833  AccountId_4841
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 45670  SubscriptionId_3829  CustomerId_3259          UGX          256
# 25855  SubscriptionId_4722  CustomerId_2728          UGX          256
# 61556  SubscriptionId_2323  CustomerId_2441          UGX          256
# 80669  SubscriptionId_3829  CustomerId_1260          UGX          256
# 35397  SubscriptionId_3829  CustomerId_4834          UGX          256
#
#          ProviderId     ProductId     ProductCategory    ChannelId  Amount  \
# 45670  ProviderId_4   ProductId_6  financial_services  ChannelId_2 -5000.0
# 25855  ProviderId_6   ProductId_3             airtime  ChannelId_3  1500.0
# 61556  ProviderId_1  ProductId_10             airtime  ChannelId_3  1000.0
# 80669  ProviderId_4   ProductId_6  financial_services  ChannelId_2 -5000.0
# 35397  ProviderId_4   ProductId_6  financial_services  ChannelId_2 -5000.0
#
#        Value      TransactionStartTime  PricingStrategy  FraudResult  \
# 45670   5000 2018-12-28 21:09:53+00:00                2            0
# 25855   1500 2018-12-14 06:00:58+00:00                2            0
# 61556   1000 2019-01-16 08:04:28+00:00                4            0
# 80669   5000 2019-02-01 09:13:41+00:00                2            0
# 35397   5000 2018-12-21 12:15:33+00:00                2            0
#
#        is_high_risk
# 45670             1
# 25855             0
# 61556             0
# 80669             0
# 35397             0

# %%
processed_df, _ = preprocess_features(df_labeled)
# Out:
# Index(['TransactionId', 'BatchId', 'AccountId', 'SubscriptionId', 'CustomerId',
#        'CurrencyCode', 'CountryCode', 'ProviderId', 'ProductId',
#        'ProductCategory', 'ChannelId', 'Amount', 'Value',
#        'TransactionStartTime', 'PricingStrategy', 'FraudResult',
#        'is_high_risk'],
#       dtype='object')

# %%
processed_df.to_csv('../data/processed/processed_data.csv', index=False)

# %%
processed_df['is_high_risk_1'].value_counts()
# Out:
# is_high_risk_1
# 0.0    94614
# 1.0     1048
# Name: count, dtype: int64

# %%
new_df, woe_df = iv_woe(processed_df, 'is_high_risk_1')
# Out:
# Information value of Amount is 0.032123
# Information value of Value is 0.158736
# Information value of ProductCategory_airtime is 0.021511
# Information value of ProductCategory_data_bundles is 0.018351
# Information value of ProductCategory_financial_services is 5.80358
# Information value of ProductCategory_movies is 1.399147
# Information value of ProductCategory_other is 0.518134
# Information value of ProductCategory_ticket is 0.096997
# Information value of ProductCategory_transport is 3.628243
# Information value of ProductCategory_tv is 3e-06
# Information value of ProductCategory_utility_bill is 0.001421
# Information value of ProviderId_ProviderId_1 is 0.002832
# Information value of ProviderId_ProviderId_2 is 0.000126
# Information value of ProviderId_ProviderId_3 is 0.022446
# Information value of ProviderId_ProviderId_4 is 0.096877
# Information value of ProviderId_ProviderId_5 is 0.289341
# Information value of ProviderId_ProviderId_6 is 0.000264
# Information value of ProductId_ProductId_1 is 0.136755
# Information value of ProductId_ProductId_10 is 4.907422
# Information value of ProductId_ProductId_11 is 0.910504
# Information value of ProductId_ProductId_12 is 2.554319
# Information value of ProductId_ProductId_13 is 0.014242
# Information value of ProductId_ProductId_14 is 0.114305
# Information value of ProductId_ProductId_15 is 0.081607
# Information value of ProductId_ProductId_16 is 0.001421
# Information value of ProductId_ProductId_19 is 0.001669
# Information value of ProductId_ProductId_2 is 0.022563
# Information value of ProductId_ProductId_20 is 0.720012
# Information value of ProductId_ProductId_21 is 0.00056
# Information value of ProductId_ProductId_22 is 0.010976
# Information value of ProductId_ProductId_23 is 0.014399
# Information value of ProductId_ProductId_24 is 0.002832
# Information value of ProductId_ProductId_27 is 0.102957
# Information value of ProductId_ProductId_3 is 4.5e-05
# Information value of ProductId_ProductId_4 is 0.001777
# Information value of ProductId_ProductId_5 is 3e-06
# Information value of ProductId_ProductId_6 is 0.002932
# Information value of ProductId_ProductId_7 is 0.046463
# Information value of ProductId_ProductId_8 is 0.109172
# Information value of ProductId_ProductId_9 is 0.000126
# Information value of PricingStrategy_0 is 2.413553
# Information value of PricingStrategy_1 is 0.009357
# Information value of PricingStrategy_2 is 0.002351
# Information value of PricingStrategy_4 is 0.00029
# Information value of ChannelId_ChannelId_1 is 0.007716
# Information value of ChannelId_ChannelId_2 is 0.072069
# Information value of ChannelId_ChannelId_3 is 2.649655
# Information value of ChannelId_ChannelId_5 is 2.880088
# Information value of FraudResult_0 is 0.012941
# Information value of FraudResult_1 is 2.827572
# Information value of is_high_risk_0 is 4.847143
# Information value of TransactionHour is 0.002275
# Information value of TransactionDay is 0.002275
# Information value of TransactionMonth is 0.010503
# Information value of TransactionYear is 0.010503

# %%
woe_df.head(15).sort_values(by='IV', ascending=False)
# Out:
#   Variable         Cutoff      N  Events  % of Events  Non-Events  \
# 4    Value            4.0  27716   146.0     0.139313     27570.0
# 2    Value            2.0  10232   159.0     0.151718     10073.0
# 3   Amount   (14.0, 16.0]  13591   104.0     0.099237     13487.0
# 1    Value            1.0  15049   210.0     0.200382     14839.0
# 3    Value            3.0  11039   158.0     0.150763     10881.0
# 0    Value            0.0  11837   165.0     0.157443     11672.0
# 0   Amount  (-0.001, 6.0]  13162   179.0     0.170802     12983.0
# 6   Amount   (19.0, 23.0]   5472    74.0     0.070611      5398.0
# 7   Amount     (6.0, 8.0]  11362   144.0     0.137405     11218.0
# 1   Amount   (11.0, 13.0]  10486   102.0     0.097328     10384.0
# 4   Amount   (16.0, 17.0]   7291    72.0     0.068702      7219.0
# 8   Amount     (8.0, 9.0]   5443    66.0     0.062977      5377.0
# 2   Amount   (13.0, 14.0]   5179    53.0     0.050573      5126.0
# 5   Amount   (17.0, 19.0]  11464   120.0     0.114504     11344.0
# 9   Amount    (9.0, 11.0]  12212   134.0     0.127863     12078.0
#
#    % of Non-Events       WoE            IV
# 4         0.291395  0.737955  1.122293e-01
# 2         0.106464 -0.354212  1.602931e-02
# 3         0.142548  0.362169  1.568588e-02
# 1         0.156837 -0.245015  1.066905e-02
# 3         0.115004 -0.270743  9.681580e-03
# 0         0.123364 -0.243919  8.312364e-03
# 0         0.137221 -0.218912  7.351231e-03
# 6         0.057053 -0.213203  2.890570e-03
# 7         0.118566 -0.147460  2.777947e-03
# 1         0.109751  0.120127  1.492329e-03
# 4         0.076299  0.104884  7.968227e-04
# 8         0.056831 -0.102691  6.311564e-04
# 2         0.054178  0.068867  2.483011e-04
# 5         0.119898  0.046031  2.482834e-04
# 9         0.127656 -0.001621  3.356120e-07
